# %%
# %load_ext autoreload
# %autoreload 2
from countries_visited_map import CountriesVisitedMap
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
map = CountriesVisitedMap()
map.add_country('France')
map.add_country('Germany')
map.add_country('Canada', year=2014, status='Lived in')
map.add_country('United States', year=2016, status='Work')
map.add_country('China', year=2016, status='Planned')

# %%
map.plot()

# %%
map.plot_status()

# %%
map.plot_timeline()
