# %%
# %load_ext autoreload
# %autoreload 2
from countries_visited_map import CountriesVisitedMap
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
map = CountriesVisitedMap()
map.add_country('Germany', 1990, status='Lived in')
map.add_country('Belgium', 1990, status='Lived in')
map.add_country('France', 2012, status='Lived in')
map.add_country('Canada', 2014, status='Lived in')

map.add_country('Luxembourg', 2000)
map.add_country('United Kingdom', 2002)
map.add_country('Netherlands', 2004)
map.add_country('Spain', 2005)
map.add_country('Greece', 2006)
map.add_country('Italy', 2007)
map.add_country('Switzerland', 2011)
map.add_country('Croatia', 2012)
map.add_country('Ireland', 2015)
map.add_country('Czech Republic', 2015)
map.add_country('United States', 2016)
map.add_country('Brazil', 2017)
map.add_country('Iceland', 2017)
map.add_country('Finland', 2024)

map.add_country('Japan', 2025, status='Planned')
map.add_country('China', 2026, status='Planned')

# %%
map.plot()

# %%
map.plot_status()
map.save('map.png')

# %%
map.plot_timeline()
